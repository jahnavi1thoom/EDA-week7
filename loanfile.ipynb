# %% [markdown]
# <a href="https://colab.research.google.com/github/jahnavi1thoom/EDA-week7/blob/main/loanfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
x=('jd','sd','m','sd','m','sd','jd','m','sd','jd','m','sd','jd','jd','m','jd','sd','jd','m','sd','m')
print(pd.Series(x))
#label encoder
le = LabelEncoder()
encoded = le.fit_transform(x)
print(encoded)
#1ord encoding
pd.get_dummies(x,dtype='int')
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
path='/content/drive/MyDrive/loan_approved.csv'
df=pd.read_csv(path)
# Out:
# 0     jd
# 1     sd
# 2      m
# 3     sd
# 4      m
# 5     sd
# 6     jd
# 7      m
# 8     sd
# 9     jd
# 10     m
# 11    sd
# 12    jd
# 13    jd
# 14     m
# 15    jd
# 16    sd
# 17    jd
# 18     m
# 19    sd
# 20     m
# dtype: object
# [0 2 1 2 1 2 0 1 2 0 1 2 0 0 1 0 2 0 1 2 1]
# Mounted at /content/drive

# %%
pd.get_dummies(df,dtype='int')
print(df.isnull().sum())
#category
print(df['Gender'].dtype)#categorical
df['Gender']=df['Gender'].fillna('unknown')#categorical
print(pd.get_dummies(df['Gender'],dtype='int'))
df['Married']=df['Married'].fillna('unknown')#categorical
pd.get_dummies(df['Married'],dtype='int',drop_first=True)
df['Dependents']=df['Dependents'].fillna('unknown')#categorical
le = LabelEncoder()
encoded = le.fit_transform(df['Dependents'])
df['Self_Employed']=df['Self_Employed'].fillna('unknown')#categorical
df['LoanAmount'] = pd.to_numeric(df['LoanAmount'], errors='coerce')#numeric
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].median())

df['Loan_Amount_Term'] = pd.to_numeric(df['Loan_Amount_Term'], errors='coerce')#numeric
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0])
df['Credit_History'] = pd.to_numeric(df['Credit_History'], errors='coerce')#numeric
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mode()[0])
print(df)
print(df.isnull().sum())
print(pd.get_dummies(df['Education'],dtype='int'))

print(pd.get_dummies(df,dtype='int'))
# 6. Final checks
print("\nDtypes after processing:\n", df.dtypes)
print("-----head-----")
print(df.head())
df.to_csv("cleaned_data.csv", index=False)
pd.read_csv("cleaned_data.csv")
# Out:
# Loan_ID                   0
# Gender                    0
# Married                   0
# Dependents                0
# Education                 0
# Self_Employed             0
# ApplicantIncome           0
# CoapplicantIncome         0
# LoanAmount                0
# Loan_Amount_Term          0
# Credit_History            0
# Property_Area             0
# Loan_Status (Approved)    0
# dtype: int64
# object
#      Female  Male  unknown
# 0         0     1        0
# 1         0     1        0
# 2         0     1        0
# 3         0     1        0
# 4         0     1        0
# ..      ...   ...      ...
# 609       1     0        0
# 610       0     1        0
# 611       0     1        0
# 612       0     1        0
# 613       1     0        0
#
# [614 rows x 3 columns]
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# ...

# %%
path='/content/drive/MyDrive/loan_approved.csv'
df1=pd.read_csv(path)
print(df1['Loan_Amount_Term'].unique())
print(df1['Loan_Amount_Term'].mean())
print("\nDtypes before processing:\n", df.dtypes)
#z-score
print((df['ApplicantIncome']-df['ApplicantIncome'].mean())/df['ApplicantIncome'].std())
# Out:
# [360. 120. 240.  nan 180.  60. 300. 480.  36.  84.  12.]
# 342.0
#
# Dtypes before processing:
#  Loan_ID                    object
# Gender                     object
# Married                    object
# Dependents                 object
# Education                  object
# Self_Employed              object
# ApplicantIncome             int64
# CoapplicantIncome         float64
# LoanAmount                float64
# Loan_Amount_Term          float64
# Credit_History            float64
# Property_Area              object
# Loan_Status (Approved)     object
# dtype: object
# 0      0.072931
# 1     -0.134302
# 2     -0.393427
# 3     -0.461686
# 4      0.097649
#          ...
# 609   -0.409796
# 610   -0.212383
# 611    0.436818
# 612    0.356773
# 613   -0.134302
# Name: ApplicantIncome, Length: 614, dtype: float64

# %% [markdown]
# 1.Identify the outliers using histogram,boxplot,skewness(skew)
# 2.whether youshould use IQR or Z-Score.if you are seeing the numerical data(cols)nature as normal or not
# if you have large no of outliers,etc use IQR
# if it looks normal but not normal then use Z-Score
# if outlier is more than 10% we cant delete outliers
# if you are keeping outliers you havee to use decision based alg
# if yu want to keep outliers and u cant use decision based alg then you can use linear based alg go for transformation techique

# %%
df['CoapplicantIncome'].kurtosis()
df['CoapplicantIncome'].skew()
df['CoapplicantIncome'].describe()
# Out:
# count      614.000000
# mean      1621.245798
# std       2926.248369
# min          0.000000
# 25%          0.000000
# 50%       1188.500000
# 75%       2297.250000
# max      41667.000000
# Name: CoapplicantIncome, dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
trans=PowerTransformer(method='yeo-johnson')

# %%
la_trans=trans.fit_transform(df[['CoapplicantIncome']])
la_trans.shape
# Out:
# (614, 1)

# %%
print('skewness:',pd.Series(la_trans.reshape(614,)).skew())
print('kurtosis',pd.Series(la_trans.reshape(614,)).kurtosis())
# Out:
# skewness: -0.14564645710551902
# kurtosis -1.8778432766544493

# %%
import seaborn as sns
sns.histplot(la_trans)
# Out:
# <Axes: ylabel='Count'>

# %%
#QQ-plot
import numpy as np
import statsmodels.api as sm
import pylab as py
data=np.random.rand(100)
sm.qqplot(data,line='45')
py.show()
